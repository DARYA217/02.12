# %% [markdown]
# <a href="https://colab.research.google.com/github/DARYA217/02.12/blob/DARYA217-patch-1/SWOT_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Группа: 20БИ-3')
print('ФИО: 'Соловьева Дарья Алексеевна')
# !ln -fs /usr/share/zoneinfo/Europe/Moscow /etc/localtime
# !date

# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
print(os.getcwd())
print(os.listdir('./'))
print(os.listdir('/content/drive'))
print(os.listdir('/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03'))
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content
# ['.config', 'drive', 'sample_data']
# ['MyDrive', '.file-revisions-by-id', '.shortcut-targets-by-id', '.Trash']
# ['Новая таблица.gsheet', 'SWOT анализ.ipynb']

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРабота с таблицей')
# %ll -lAF /content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/Новая таблица.gsheet')
table = gs.open_by_key('1yp3nAgGSGEhs4zAqSEMTVWkmWBUe1Qa8jxKLAsvAfJU')
print(dir(table))
worksheet = table.worksheet('list1')
rows = worksheet.get_all_values()
print(rows)
strength = [0] * 6
s=0
opportunities = [0] * 6
o = 0
weakness = [0] * 6
w = 0
threats = [0] * 6
t = 0
flag = 'strength'
for i in rows:
  if i[0] == 'strength':
    flag = 'strength'
  if i[0] == 'weakness':
    flag = 'weakness'
  if i[0] == 'opportunities':
    flag = 'opportunities'
  if i[0] == 'threats':
    flag = 'threats'
  if flag == 'strength' and i[4] != '' and i[4] != 'power':
    strength[s] = i[4]
    s = s + 1
  if flag == 'opportunities' and i[4] != '' and i[4] != 'power':
    opportunities[o] = i[4]
    o = o + 1
  if flag == 'weakness' and i[4] != '' and i[4] != 'power':
    weakness[w] = i[4]
    w = w + 1
  if flag == 'threats' and i[4] != '' and i[4] != 'power':
    threats[t] = i[4]
    t = t + 1
print(strength)
print(opportunities)
print(weakness)
print(threats)
streng = 0
opport = 0
weak = 0
threat = 0
for i in strength:
  streng = streng + float(i)
for i in opportunities:
  opport = opport + float(i)
for i in weakness:
  weak = weak + float(i)
for i in threats:
  threat = threat + float(i)
worksheet.update('A43', 'strength ' + str(s))
worksheet.update('B43', 'weakness ' + str(w))
worksheet.update('C43', 'opportunities ' + str(o))
worksheet.update('D43', 'threats ' + str(t))
worksheet.update('A44', 'sum power ' + str(s + o - w - t))
prob = (s + o) / (s + o + w + t)
worksheet.update('B44', 'Probability of good result ' + str(prob))
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.2)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
#
# Работа с таблицей
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks/SWOT': No such file or directory
# ls: cannot access 'анализ': No such file or directory
# ls: cannot access '03.03/': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# [['кальянная', '', '', '', ''], ['strength', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['популярность подобных заведений', 'посетители часто ходят', '10', '0.9', '9'], ['наличие сайта и официальной страницы в соцсетях', 'люди могут увидеть рекомендации в соцсетях и заитересоваься заведением', '9', '0.9', '8.1'], ['удобный интерфейс сайта', 'возможности, которых нет у многих заведений данного типа', '10', '1', '10'], ['высокий уровень обслуживания и взаимодействия с клиентами', 'вежливые и общительные официанты', '8', '0.7', '5.6'], ['weakness', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['высокая арендная плата', 'обеспечить стабильную выручку в месяц, возможность на основе этого получить скидку на аренду', '7', '0.7', '4.9'], ['тренд на подобные заведения может так же быстро уйти', 'возможность не просто курить кальян, но и приятно провести вечер за просмотром фильмов и игрой на приставке', '8', '0.9', '7.2'], ['ограниченность клиентсой базы', 'возможность заказать столик без кальяна, но с настольными играми', '6', '0.5', '3'], ['высокие затраты на приобретение сырья', 'стабильное партнерство с возможностью получения скидки', '8', '0.8', '6.4'], ['opportunities', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['создание уникального интерьера заведения', 'что привлечет новых клиентов', '10', '0.9', '9'], ['высококачественное оборудование', 'клиент будет доволен качеством предоставленных услуг', '10', '1', '10'], ['боьшой ассортимент', 'постоянное добавление новой продукции в плане ассортиментного ряда', '10', '0.9', '9'], ['удержание клиентов', 'система постоянного партнёрства, долгосрочных отношений с клиентами', '8', '0.7', '5.6'], ['threats', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['пандемия коронавируса', '', '4', '0.5', '2'], ['ужесточение законодательства', '', '10', '0.5', '5'], ['высокая конкуренция', 'постоянное развитие, чтобы удерживать старых и привлекать новых посетителей', '8', '0.8', '6.4'], ['неадекватное поведение некоторых посетителей', 'усиленный фейс-контроль', '2', '0.8', '1.6']]
# ['9', '8.1', '10', '5.6', 0, 0]
# ['9', '10', '9', '5.6', 0, 0]
# ['4.9', '7.2', '3', '6.4', 0, 0]
# ['2', '5', '6.4', '1.6', 0, 0]
# {'spreadsheetId': '1yp3nAgGSGEhs4zAqSEMTVWkmWBUe1Qa8jxKLAsvAfJU',
#  'updatedCells': 1,
#  'updatedColumns': 1,
#  'updatedRange': 'list1!B44',
#  'updatedRows': 1}

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll - /content/drive/MyDrive/Colab Notebooks
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/Новая таблица.gsheet')
table = gs.open_by_key('1yp3nAgGSGEhs4zAqSEMTVWkmWBUe1Qa8jxKLAsvAfJU')
print(dir(table))
worksheet = table.worksheet('list1')
rows = worksheet.get_all_values()
print(rows)
strength = [0] * 6
s = 0
opportunities = [0] * 6
o = 0
weakness = [0] * 6
w = 0
threats = [0] * 6
t = 0
flag = 'strength'
for i in rows:
  if i[0] == 'strength':
    flag = 'strength'
  if i[0] == 'weakness':
    flag = 'weakness'
  if i[0] == 'opportunities':
    flag = 'opportunities'
  if i[0] == 'threats':
    flag = 'threats'
  if flag == 'strength' and i[4] != '' and i[4] != 'power':
    strength[s] = i[4]
    s = s + 1
  if flag == 'opportunities' and i[4] != '' and i[4] != 'power':
    opportunities[o] = i[4]
    o = o + 1
  if flag == 'weakness' and i[4] != '' and i[4] != 'power':
    weakness[w] = i[4]
    w = w + 1
  if flag == 'threats' and i[4] != '' and i[4] != 'power':
    threats[t] = i[4]
    t = t + 1
print(strength)
print(opportunities)
print(weakness)
print(threats)
streng = 0
opport = 0
weak = 0
threat = 0
for i in strength:
  streng = streng + float(i)
for i in opportunities:
  opport = opport + float(i)
for i in weakness:
  weak = weak + float(i)
for i in threats:
  threat = threat + float(i)
  import matplotlib.pyplot as plt
x=list()
x_float=list()
title=list()
y_float=list()
    
title = [ "strengths", "weaknesses", "opportunities", "threats", "result"]
x=title
x_float = [1, 2, 3, 4, 5]
result = streng - 1*weak + opport - 1*threat
y = [streng, weak, opport, threat]
y_float = [streng, -1*weak, opport, -1*threat,  result]
print(x_float,title,y_float)
print('списки формированы-->\n')
x_pos=list()
for i in range(x_float.__len__()):
    x_pos.append(i)
print('<!--разбивка по абсцисс и значения ординат\n', len( x_float), x_pos, y_float, ' -->\n')

fig=plt.figure(figsize=(8,6), dpi=72)
plt.bar(x_pos, y_float, width=0.75, align='edge', alpha=0.4)
plt.xticks(x_pos,  x_float, fontsize=14)
plt.xlabel('Обозначения1', fontsize=14)
plt.ylabel('Мощность воздействия', fontsize=14)
plt.title('SWOT', fontsize=14)
plt.grid(True, color='r', linestyle='-', linewidth=2)
#plt.draw()
plt.show()
fig.savefig("/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/result/hookahbar.png")
print('<div class="d-flex flex-row ">')
print('<div class="card m-1" style="width: 28rem;">',
      '<img  src="/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/result/hookahbar.png" class="card-img-top" alt="...">',
      '<div class="card-body">')
    
for i in range(title.__len__()):
    print(i+1, " - ", title[i], "; ")
    i += 1
print('</div>', '</div>')
print('<div>')
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.2)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
#
# Работаем с таблицей
# ls: cannot access '-': No such file or directory
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# [['кальянная', '', '', '', ''], ['strength', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['популярность подобных заведений', 'посетители часто ходят', '10', '0.9', '9'], ['наличие сайта и официальной страницы в соцсетях', 'люди могут увидеть рекомендации в соцсетях и заитересоваься заведением', '9', '0.9', '8.1'], ['удобный интерфейс сайта', 'возможности, которых нет у многих заведений данного типа', '10', '1', '10'], ['высокий уровень обслуживания и взаимодействия с клиентами', 'вежливые и общительные официанты', '8', '0.7', '5.6'], ['weakness', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['высокая арендная плата', 'обеспечить стабильную выручку в месяц, возможность на основе этого получить скидку на аренду', '7', '0.7', '4.9'], ['тренд на подобные заведения может так же быстро уйти', 'возможность не просто курить кальян, но и приятно провести вечер за просмотром фильмов и игрой на приставке', '8', '0.9', '7.2'], ['ограниченность клиентсой базы', 'возможность заказать столик без кальяна, но с настольными играми', '6', '0.5', '3'], ['высокие затраты на приобретение сырья', 'стабильное партнерство с возможностью получения скидки', '8', '0.8', '6.4'], ['opportunities', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['создание уникального интерьера заведения', 'что привлечет новых клиентов', '10', '0.9', '9'], ['высококачественное оборудование', 'клиент будет доволен качеством предоставленных услуг', '10', '1', '10'], ['боьшой ассортимент', 'постоянное добавление новой продукции в плане ассортиментного ряда', '10', '0.9', '9'], ['удержание клиентов', 'система постоянного партнёрства, долгосрочных отношений с клиентами', '8', '0.7', '5.6'], ['threats', '', '', '', ''], ['name', 'actions', 'importance', 'probability', 'power'], ['пандемия коронавируса', '', '4', '0.5', '2'], ['ужесточение законодательства', '', '10', '0.5', '5'], ['высокая конкуренция', 'постоянное развитие, чтобы удерживать старых и привлекать новых посетителей', '8', '0.8', '6.4'], ['неадекватное поведение некоторых посетителей', 'усиленный фейс-контроль', '2', '0.8', '1.6'], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['', '', '', '', ''], ['strength 4', 'weakness 4', 'opportunities 4', 'threats 4', ''], ['sum power 0', 'Probability of good result 0.5', '', '', '']]
# ['9', '8.1', '10', '5.6', 0, 0]
# ['9', '10', '9', '5.6', 0, 0]
# ['4.9', '7.2', '3', '6.4', 0, 0]
# ['2', '5', '6.4', '1.6', 0, 0]
# [1, 2, 3, 4, 5] ['strengths', 'weaknesses', 'opportunities', 'threats', 'result'] [32.7, -21.5, 33.6, -15.0, 29.800000000000004]
# списки формированы-->
#
# <!--разбивка по абсцисс и значения ординат
#  5 [0, 1, 2, 3, 4] [32.7, -21.5, 33.6, -15.0, 29.800000000000004]  -->
# <div class="d-flex flex-row ">
# <div class="card m-1" style="width: 28rem;"> <img  src="/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/result/hookahbar.png" class="card-img-top" alt="..."> <div class="card-body">
# 1  -  strengths ;
# 2  -  weaknesses ;
# 3  -  opportunities ;
# 4  -  threats ;
# 5  -  result ;
# </div> </div>
# <div>

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll -lAF /content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/Новая таблица.gsheet')
table = gs.open_by_key('1yp3nAgGSGEhs4zAqSEMTVWkmWBUe1Qa8jxKLAsvAfJU')
print(dir(table))
worksheet = table.worksheet('list2')
rows = worksheet.get_all_values()
name = list()
actions = list()
importance = list()
probability = list()
power = list()
power_sh = list()
power_raw = list()
i=0
for row in rows:
  if(i>0):
    print (i, row)
    name.append(row[0])
    importance.append(int(row[2]))
    probability.append(float(row[3]))
    power.append(int(row[2])*float(row[3]))
    power_raw = list()
    power_raw.append(int(row[2])*float(row[3]))
    power_sh.append(power_raw)
  i+=1
print(power_sh)
worksheet.update('E2:E10', power_sh)
result = sum(power)
worksheet.update('G3','Суммарная power:')
worksheet.update('H3',result)
print('Суммарная Power strengths составляет:', result)

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

i=0
line= list()
cols=worksheet.col_values(1)
for col in cols:
  if (i>0):
    line.append(i)
  i+=1

powers = power
x = np.arange(len(line))  
width = 0.6  
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, powers, width)
a=worksheet.col_values(1)
ax.set_ylabel('Мощность воздействия')
ax.set_title('Strengths')
ax.set_xlabel('Обозначения')
ax.set_xticks(x)
ax.set_xticklabels(line)
fig.tight_layout()
plt.show()
k=0

for col in cols:
  if(k>0):
    print (k,'- ', col)
  k+=1
# !date
# Out:
# Collecting gspread
#   Downloading https://files.pythonhosted.org/packages/df/f0/e345e7159c89b898f183cc40ed9909619475492bb000652d709f395f096a/gspread-3.7.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.3)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Installing collected packages: gspread
#   Found existing installation: gspread 3.0.1
#     Uninstalling gspread-3.0.1:
#       Successfully uninstalled gspread-3.0.1
# Successfully installed gspread-3.7.0
#
# Работаем с таблицей
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks/SWOT': No such file or directory
# ls: cannot access 'анализ': No such file or directory
# ls: cannot access '03.03': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# 1 ['популярность подобных заведений', 'посетители часто ходят', '10', '0.9', '9', '', 'power:', '32.7']
# 2 ['наличие сайта и официальной страницы в соцсетях', 'люди могут увидеть рекомендации в соцсетях и заитересоваься заведением', '9', '0.9', '8.1', '', '', '']
# 3 ['удобный интерфейс сайта', 'возможности, которых нет у многих заведений данного типа', '10', '1', '10', '', '', '']
# 4 ['высокий уровень обслуживания и взаимодействия с клиентами', 'вежливые и общительные официанты', '8', '0.7', '5.6', '', '', '']
# [[9.0], [8.1], [10.0], [5.6]]
# Суммарная Power strengths составляет: 32.7
# 1 -  популярность подобных заведений
# 2 -  наличие сайта и официальной страницы в соцсетях
# 3 -  удобный интерфейс сайта
# 4 -  высокий уровень обслуживания и взаимодействия с клиентами
# Tue Mar 16 10:08:32 UTC 2021

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll -lAF /content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/Новая таблица.gsheet')
table = gs.open_by_key('1yp3nAgGSGEhs4zAqSEMTVWkmWBUe1Qa8jxKLAsvAfJU')
print(dir(table))
worksheet = table.worksheet('list3')
rows = worksheet.get_all_values()
name = list()
actions = list()
importance = list()
probability = list()
power = list()
power_sh = list()
power_raw = list()
i=0
for row in rows:
  if(i>0):
    print (i, row)
    name.append(row[0])
    importance.append(int(row[2]))
    probability.append(float(row[3]))
    power.append(int(row[2])*float(row[3]))
    power_raw = list()
    power_raw.append(int(row[2])*float(row[3]))
    power_sh.append(power_raw)
  i+=1
print(power_sh)
worksheet.update('E2:E10', power_sh)
result = sum(power)
worksheet.update('G3','Суммарная power:')
worksheet.update('H3',result)
print('Суммарная Power weaknesses составляет:', result)

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

i=0
line= list()
cols=worksheet.col_values(1)
for col in cols:
  if (i>0):
    line.append(i)
  i+=1

powers = power
x = np.arange(len(line))  
width = 0.6  
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, powers, width)
a=worksheet.col_values(1)
ax.set_ylabel('Мощность воздействия')
ax.set_title('weaknesses')
ax.set_xlabel('Обозначения')
ax.set_xticks(x)
ax.set_xticklabels(line)
fig.tight_layout()
plt.show()
k=0

for col in cols:
  if(k>0):
    print (k,'- ', col)
  k+=1
# !date
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.3)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
#
# Работаем с таблицей
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks/SWOT': No such file or directory
# ls: cannot access 'анализ': No such file or directory
# ls: cannot access '03.03': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# 1 ['высокая арендная плата', 'обеспечить стабильную выручку в месяц, возможность на основе этого получить скидку на аренду', '7', '0.7', '4.9', '', 'power:', '21.5']
# 2 ['тренд на подобные заведения может так же быстро уйти', 'возможность не просто курить кальян, но и приятно провести вечер за просмотром фильмов и игрой на приставке', '8', '0.9', '7.2', '', '', '']
# 3 ['ограниченность клиентсой базы', 'возможность заказать столик без кальяна, но с настольными играми', '6', '0.5', '3', '', '', '']
# 4 ['высокие затраты на приобретение сырья', 'стабильное партнерство с возможностью получения скидки', '8', '0.8', '6.4', '', '', '']
# [[4.8999999999999995], [7.2], [3.0], [6.4]]
# Суммарная Power weaknesses составляет: 21.5
# 1 -  высокая арендная плата
# 2 -  тренд на подобные заведения может так же быстро уйти
# 3 -  ограниченность клиентсой базы
# 4 -  высокие затраты на приобретение сырья
# Tue Mar 16 10:10:24 UTC 2021

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll -lAF /content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/Новая таблица.gsheet')
table = gs.open_by_key('1yp3nAgGSGEhs4zAqSEMTVWkmWBUe1Qa8jxKLAsvAfJU')
print(dir(table))
worksheet = table.worksheet('list4')
rows = worksheet.get_all_values()
name = list()
actions = list()
importance = list()
probability = list()
power = list()
power_sh = list()
power_raw = list()
i=0
for row in rows:
  if(i>0):
    print (i, row)
    name.append(row[0])
    importance.append(int(row[2]))
    probability.append(float(row[3]))
    power.append(int(row[2])*float(row[3]))
    power_raw = list()
    power_raw.append(int(row[2])*float(row[3]))
    power_sh.append(power_raw)
  i+=1
print(power_sh)
worksheet.update('E2:E10', power_sh)
result = sum(power)
worksheet.update('G3','Суммарная power:')
worksheet.update('H3',result)
print('Суммарная Power opportunities составляет:', result)

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

i=0
line= list()
cols=worksheet.col_values(1)
for col in cols:
  if (i>0):
    line.append(i)
  i+=1

powers = power
x = np.arange(len(line))  
width = 0.6  
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, powers, width)
a=worksheet.col_values(1)
ax.set_ylabel('Мощность воздействия')
ax.set_title('opportunities')
ax.set_xlabel('Обозначения')
ax.set_xticks(x)
ax.set_xticklabels(line)
fig.tight_layout()
plt.show()
k=0

for col in cols:
  if(k>0):
    print (k,'- ', col)
  k+=1
# !date
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.3)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.1)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
#
# Работаем с таблицей
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks/SWOT': No such file or directory
# ls: cannot access 'анализ': No such file or directory
# ls: cannot access '03.03': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# 1 ['создание уникального интерьера заведения', 'что привлечет новых клиентов', '10', '0.9', '9', '', 'power:', '33.6']
# 2 ['высококачественное оборудование', 'клиент будет доволен качеством предоставленных услуг', '10', '1', '10', '', '', '']
# 3 ['боьшой ассортимент', 'постоянное добавление новой продукции в плане ассортиментного ряда', '10', '0.9', '9', '', '', '']
# 4 ['удержание клиентов', 'система постоянного партнёрства, долгосрочных отношений с клиентами', '8', '0.7', '5.6', '', '', '']
# [[9.0], [10.0], [9.0], [5.6]]
# Суммарная Power opportunities составляет: 33.6
# 1 -  создание уникального интерьера заведения
# 2 -  высококачественное оборудование
# 3 -  боьшой ассортимент
# 4 -  удержание клиентов
# Tue Mar 16 10:12:38 UTC 2021

# %%
import os
import time
from google.colab import auth
auth.authenticate_user()
# !pip install --upgrade gspread
import gspread
from oauth2client.client import GoogleCredentials
print('\nРаботаем с таблицей')
# %ll -lAF /content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03
gs = gspread.authorize(GoogleCredentials.get_application_default())
os.stat('/content/drive/MyDrive/Colab Notebooks/SWOT анализ 03.03/Новая таблица.gsheet')
table = gs.open_by_key('1yp3nAgGSGEhs4zAqSEMTVWkmWBUe1Qa8jxKLAsvAfJU')
print(dir(table))
worksheet = table.worksheet('list5')
rows = worksheet.get_all_values()
name = list()
actions = list()
importance = list()
probability = list()
power = list()
power_sh = list()
power_raw = list()
i=0
for row in rows:
  if(i>0):
    print (i, row)
    name.append(row[0])
    importance.append(int(row[2]))
    probability.append(float(row[3]))
    power.append(int(row[2])*float(row[3]))
    power_raw = list()
    power_raw.append(int(row[2])*float(row[3]))
    power_sh.append(power_raw)
  i+=1
print(power_sh)
worksheet.update('E2:E10', power_sh)
result = sum(power)
worksheet.update('G3','Суммарная power:')
worksheet.update('H3',result)
print('Суммарная Power threats составляет:', result)

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

i=0
line= list()
cols=worksheet.col_values(1)
for col in cols:
  if (i>0):
    line.append(i)
  i+=1

powers = power
x = np.arange(len(line))  
width = 0.6  
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, powers, width)
a=worksheet.col_values(1)
ax.set_ylabel('Мощность воздействия')
ax.set_title('threats')
ax.set_xlabel('Обозначения')
ax.set_xticks(x)
ax.set_xticklabels(line)
fig.tight_layout()
plt.show()
k=0

for col in cols:
  if(k>0):
    print (k,'- ', col)
  k+=1
# !date
# Out:
# Requirement already up-to-date: gspread in /usr/local/lib/python3.7/dist-packages (3.7.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from gspread) (1.27.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from gspread) (0.4.3)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.7.2)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (4.2.1)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (54.0.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.12.0->gspread) (1.15.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.23.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
#
# Работаем с таблицей
# ls: cannot access '/content/drive/MyDrive/Colab': No such file or directory
# ls: cannot access 'Notebooks/SWOT': No such file or directory
# ls: cannot access 'анализ': No such file or directory
# ls: cannot access '03.03': No such file or directory
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_properties', '_spreadsheets_get', '_spreadsheets_sheets_copy_to', 'add_worksheet', 'batch_update', 'client', 'del_worksheet', 'duplicate_sheet', 'fetch_sheet_metadata', 'get_worksheet', 'id', 'list_permissions', 'remove_permissions', 'reorder_worksheets', 'share', 'sheet1', 'title', 'updated', 'url', 'values_append', 'values_batch_get', 'values_batch_update', 'values_clear', 'values_get', 'values_update', 'worksheet', 'worksheets']
# 1 ['пандемия коронавируса', '', '4', '0.5', '2', '', '', '']
# 2 ['ужесточение законодательства', '', '10', '0.5', '5', '', 'power:', '15']
# 3 ['высокая конкуренция', 'постоянное развитие, чтобы удерживать старых и привлекать новых посетителей', '8', '0.8', '6.4', '', '', '']
# 4 ['неадекватное поведение некоторых посетителей', 'усиленный фейс-контроль', '2', '0.8', '1.6', '', '', '']
# [[2.0], [5.0], [6.4], [1.6]]
# Суммарная Power threats составляет: 15.0
# 1 -  пандемия коронавируса
# 2 -  ужесточение законодательства
# 3 -  высокая конкуренция
# 4 -  неадекватное поведение некоторых посетителей
# Tue Mar 16 10:13:42 UTC 2021
